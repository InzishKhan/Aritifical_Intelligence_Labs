# %% [markdown]
# **Question No.1**

# %%
import numpy as np

Initial_weights = [1.0, 1.0]
Initial_bias = 1.0
learning_rate=0.1
max_iterations=1000
# Defining the sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Perceptron learning algorithm
def perceptron_learning(inputs, labels, initial_weights, initial_bias):
    # Initialize weights and bias
    weights = np.array(initial_weights)
    bias = initial_bias

    # Initialize convergence flag
    converge = False
    iterations = 0

    while not converge and iterations < max_iterations:
        converge = True

        for input, label in zip(inputs, labels):
            # Computing the z summation value
            zsum = np.dot(input, weights) + bias

            # computing ypred using the sigmoid activation function
            ypred = sigmoid(zsum)

            # Updating weights if actual is not equal to predicted
            if ypred != label:
                converge = False
                #updating weights
                weights += learning_rate * (label - ypred) * input
                #updating bias
                bias += learning_rate * (label - ypred)

        iterations += 1

    return weights, bias

# AND Gate Perceptron Learning
ANDInput = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
ANDLabels = np.array([0, 0, 0, 1])
# Learning Weights that will provide the correct classification
finalANDweights, finalANDbias = perceptron_learning(ANDInput, ANDLabels, Initial_weights, Initial_bias)
print("Final weights for AND Gate :", finalANDweights)
print("Final bias for AND Gate :", finalANDbias)

# OR Gate   Perceptron Learning
ORInput = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
ORLabels = np.array([0, 1, 1, 1])
# Perceptron Learning in accordance with 'OR GATE'
finalORweights, finalORbias = perceptron_learning(ORInput, ORLabels, Initial_weights, Initial_bias)
#output for the learned weights for the correctly classifying ypredicted
print("Final weights for OR Gate :", finalORweights)
print("Final bias for OR Gate :", finalORbias)

# Testing AND gate perceptron
print("\nTesting the trained perceptron on AND gate inputs:")
for inputs in ANDInput:
    zsum = np.dot(inputs, finalANDweights) + finalANDbias
    ypred = sigmoid(zsum)
    # Modify predicted output based on threshold
    if ypred > 0.5:
        ypred = 1
    else:
        ypred = 0
    print(f"Inputs: {inputs}, Predicted Output: {ypred}")


print("\nTesting the trained perceptron on OR gate inputs:")

for inputs in ORInput:
    zsum = np.dot(inputs, finalORweights) + finalORbias
    ypred = sigmoid(zsum)
    # Modify predicted output based on threshold
    if ypred > 0.5:
        ypred = 1
    else:
        ypred = 0
    print(f"Inputs: {inputs}, Predicted Output: {ypred}")
# Out:
# Final weights for AND Gate : [5.61665485 5.61060231]
# Final bias for AND Gate : -8.588678182412002
# Final weights for OR Gate : [6.81165138 6.81524057]
# Final bias for OR Gate : -2.9282891743610717
#
# Testing the trained perceptron on AND gate inputs:
# Inputs: [0 0], Predicted Output: 0
# Inputs: [0 1], Predicted Output: 0
# Inputs: [1 0], Predicted Output: 0
# Inputs: [1 1], Predicted Output: 1
#
# Testing the trained perceptron on OR gate inputs:
# Inputs: [0 0], Predicted Output: 0
# Inputs: [0 1], Predicted Output: 1
# Inputs: [1 0], Predicted Output: 1
# Inputs: [1 1], Predicted Output: 1

# %% [markdown]
# **Question No.2 **

# %%
import pandas as pd
df=pd.read_csv('horseRacing.csv')
df
# Out:
#        race_id  horse_id  1-101  1-102  1-103  1-104  1-105  1-106  1-107  \
# 0       495886    565129    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1       495886    607093    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2       495886    637337    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3       495886    659819    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4       495886    661530    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...        ...       ...    ...    ...    ...    ...    ...    ...    ...
# 98385   691981   1770390    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98386   691981   1770391    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98387   719014    901847    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98388   719014    904955    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98389   719014   1247025    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        1-108  ...  3-132  4-105  4-109  4-110  4-114  4-115  4-116  4-117  \
# 0      -0.71  ...  -1.16    0.0   1.87   1.87 -2.070  -1.96 -1.950  -0.30
# 1      -0.05  ...   0.77    0.0   0.00   0.00  0.000   0.00  0.000   0.07
# 2      -0.97  ...  -1.16    0.0   0.00   0.00  0.480   0.44  0.390  -0.86
# 3       0.21  ...   0.77    0.0   0.00   0.00  0.320   1.09  0.780  -0.86
# 4       0.08  ...   0.77    0.0   0.00   0.00  0.000   0.00  0.390   1.17
# ...      ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 98385    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98386    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 98387    NaN  ...    NaN    NaN  -0.71  -0.71  0.740   0.71  0.770   0.71
# 98388    NaN  ...    NaN    NaN   0.71   0.71 -0.670  -0.71 -0.640  -0.71
# 98389    NaN  ...    NaN    NaN   0.00   0.00  0.035   0.00  0.065   0.00
#
#        calc_position  price
# 0                8.0   17.0
# 1                5.0   26.0
# 2                7.0   17.0
# 3                1.0    4.0
# 4                4.0    7.0
# ...              ...    ...
# 98385            6.0   11.0
# 98386           16.0   81.0
# 98387            1.0    3.1
# 98388            2.0    7.0
# 98389            3.0   14.0
#
# [98390 rows x 64 columns]

# %%
df.describe()
# Out:
#              race_id      horse_id         1-101         1-102         1-103  \
# count   98390.000000  9.839000e+04  33668.000000  33788.000000  33749.000000
# mean   593346.525999  8.219212e+05     -0.035803     -0.038562     -0.040769
# std     55771.004433  1.529959e+05      0.731264      0.728135      0.728328
# min    495886.000000  6.496000e+03     -2.880000     -2.370000     -2.700000
# 25%    544068.000000  7.474402e+05     -0.470000     -0.480000     -0.490000
# 50%    591423.000000  8.012120e+05     -0.120000     -0.060000     -0.030000
# 75%    641592.000000  8.578128e+05      0.040000      0.100000      0.140000
# max    719014.000000  2.501738e+06      4.760000      4.660000      4.200000
#
#               1-104         1-105         1-106         1-107         1-108  \
# count  28734.000000  28830.000000  28830.000000  28825.000000  76209.000000
# mean      -0.046150     -0.062234     -0.048450     -0.058985     -0.000095
# std        0.685621      0.683572      0.679605      0.682367      0.877625
# min       -2.560000     -2.160000     -2.500000     -2.290000     -3.390000
# 25%       -0.470000     -0.485000     -0.460000     -0.480000     -0.570000
# 50%       -0.010000     -0.110000     -0.020000     -0.110000      0.000000
# 75%        0.140000      0.010000      0.100000      0.010000      0.580000
# max        4.380000      4.180000      4.570000      4.560000      3.230000
#
#        ...         3-132         4-105         4-109         4-110  \
# count  ...  87428.000000  73839.000000  88958.000000  88446.000000
# mean   ...     -0.001547     -0.081940     -0.003415     -0.003084
# std    ...      0.914389      0.771886      0.897224      0.897800
# min    ...     -2.400000     -2.140000     -3.880000     -3.180000
# 25%    ...     -0.650000     -0.540000     -0.620000     -0.610000
# 50%    ...     -0.450000     -0.370000      0.000000      0.000000
# 75%    ...      0.610000      0.000000      0.590000      0.580000
# max    ...      4.420000      4.830000      3.750000      3.910000
#
#               4-114         4-115         4-116         4-117  calc_position  \
# count  88571.000000  88038.000000  86988.000000  88920.000000   98386.000000
# mean       0.047144      0.058346      0.100101     -0.008975       5.926687
# std        0.902434      0.906370      0.916024      0.906862       3.903444
# min       -3.370000     -3.340000     -2.970000     -2.400000       0.000000
# 25%       -0.570000     -0.570000     -0.540000     -0.640000       3.000000
# 50%        0.000000      0.000000      0.000000     -0.320000       5.000000
# 75%        0.660000      0.670000      0.700000      0.470000       8.000000
# max        3.800000      4.040000      3.890000      4.260000      31.000000
#
#               price
# count  98390.000000
# mean      20.720690
# std       30.391718
# min        0.000000
# 25%        6.000000
# 50%       12.000000
# 75%       24.000000
# max     1001.000000
#
# [8 rows x 64 columns]

# %%
df[['1-102','1-102','1-103','1-104','1-105','1-106','1-107']].isnull().sum()
# as there are so many null values in the column so it is better to drop them as they might not be useful in the predicting
# Out:
# 1-102    64602
# 1-102    64602
# 1-103    64641
# 1-104    69656
# 1-105    69560
# 1-106    69560
# 1-107    69565
# dtype: int64

# %%
df.dropna()
# Out:
#        race_id  horse_id  1-101  1-102  1-103  1-104  1-105  1-106  1-107  \
# 278     497240    589032   1.10   0.52   0.45   0.35   0.27   1.62   2.23
# 279     497240    658587   0.47   0.41  -0.54   0.94   0.78   0.28  -0.17
# 280     497240    669234  -0.62  -1.20  -0.64   0.04  -0.27  -0.13  -0.80
# 281     497240    693225  -0.55  -1.19  -1.23  -1.21  -1.09  -1.49  -1.13
# 282     497240    693680  -0.87  -0.88  -0.75  -0.04  -0.32  -0.22  -0.75
# ...        ...       ...    ...    ...    ...    ...    ...    ...    ...
# 98326   691538    856440  -0.51  -0.59  -0.48  -0.55  -0.73  -0.44  -0.27
# 98327   691538    859919   1.72   1.38   1.54   0.29   1.42   0.12   0.89
# 98328   691538    861917  -0.61  -0.81  -0.85  -0.67  -0.71  -0.69  -0.91
# 98329   691538    879810  -0.64  -0.73  -0.68  -0.71  -0.68  -0.68  -0.91
# 98330   691538    880073   0.04   0.75   0.47   1.63   0.70   1.69   1.21
#
#        1-108  ...  3-132  4-105  4-109  4-110  4-114  4-115  4-116  4-117  \
# 278     0.06  ...  -0.39  -0.47  -0.16   0.70  -0.61  -0.55  -0.71  -0.37
# 279     0.94  ...  -0.39   2.85  -1.01  -1.01   1.83   1.85   1.77   2.59
# 280    -0.81  ...  -0.39  -0.52  -0.16  -0.16   0.00  -0.18   0.00  -0.61
# 281    -1.60  ...  -0.39  -0.44   0.70   0.70  -0.15  -0.37   0.00  -0.48
# 282     0.59  ...  -0.39  -0.53  -0.16   0.70   0.46   0.18   0.35  -0.77
# ...      ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 98326  -1.02  ...   0.24  -0.49   1.40   1.00  -0.86  -0.70  -0.81  -0.30
# 98327   0.54  ...  -0.96   0.32  -0.35   0.00   0.25   0.28   0.20   1.00
# 98328  -0.69  ...   1.43  -0.59   0.53   1.00  -0.99  -0.99  -0.81  -0.61
# 98329  -0.28  ...  -0.96  -0.85  -0.35  -1.00   0.12   0.28   0.20  -1.17
# 98330   1.45  ...   0.24   1.61  -1.23  -1.00   1.48   1.55   1.62   1.08
#
#        calc_position  price
# 278              6.0  17.00
# 279              8.0   7.00
# 280              4.0   6.50
# 281             10.0  23.00
# 282              7.0  13.00
# ...              ...    ...
# 98326            3.0  34.00
# 98327            1.0   2.38
# 98328            2.0  11.00
# 98329            3.0  21.00
# 98330            3.0   1.83
#
# [12520 rows x 64 columns]

# %%
#removing outliers
df = df[(df >= df.quantile(0.05)) & (df <= df.quantile(0.95))].dropna()

# %%
# Convert labels into 0 or 1 based on threshold
threshold = 0.5
df['calc_position'] = (df['calc_position'] > threshold).astype(int)
df['calc_position']
# Out:
# 5510     1
# 5654     1
# 5661     1
# 6013     1
# 6999     1
#         ..
# 91856    1
# 92062    1
# 92937    1
# 93256    1
# 93337    1
# Name: calc_position, Length: 314, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[['race_id','horse_id','calc_position','price']])
plt.title('Boxplot of Numerical Columns')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 8))
df.hist(bins=20, figsize=(20, 10))
plt.suptitle('Histograms')
plt.show()

# %% [markdown]
# The range of the values within the colums have negative values which we can cater them by applying bining which might be helpful..Also there might me columns that do not contribute in the predicting so it is helpful to remove them form our dataset as they may be consuming unnecessary information

# %%
df1 = pd.get_dummies(df, columns=['race_id'])
print(df1)
# Out:
#        horse_id  1-101  1-102  1-103  1-104  1-105  1-106  1-107  1-108  \
# 5510   735850.0  0.800  0.440  0.060 -0.335  -0.36 -0.405 -0.475  -0.63
# 5654   673833.0  0.200  0.180  0.020  0.000   0.00  0.000  0.000  -0.27
# 5661   754817.0  0.200  0.180  0.020  0.000   0.00  0.000  0.000  -1.11
# 6013   667129.0 -0.330 -0.380 -0.140 -0.190  -0.36 -0.280 -0.630  -0.16
# 6999   762741.0 -0.390 -0.280 -0.350 -0.150  -0.18 -0.160 -0.640  -0.01
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 91856  862852.0 -0.670 -0.460 -0.370 -0.070  -0.47  0.080  0.010  -0.43
# 92062  900773.0 -0.200  0.310  0.500 -0.280  -0.33  0.130  0.810   1.13
# 92937  808422.0  0.710  0.200  0.530 -0.160   0.42 -0.130 -0.250   1.27
# 93256  903163.0 -0.490 -0.690 -0.850  0.800   0.13 -0.060 -0.290   0.34
# 93337  898066.0  0.205 -0.075 -0.185 -0.500  -0.48 -0.400 -0.010  -0.52
#
#        1-109  ...  race_id_672954.0  race_id_673724.0  race_id_674258.0  \
# 5510    1.16  ...                 0                 0                 0
# 5654    0.59  ...                 0                 0                 0
# 5661   -0.45  ...                 0                 0                 0
# 6013   -0.39  ...                 0                 0                 0
# 6999    0.07  ...                 0                 0                 0
# ...      ...  ...               ...               ...               ...
# 91856  -0.84  ...                 0                 0                 0
# 92062   0.11  ...                 0                 0                 0
# 92937  -1.06  ...                 0                 0                 0
# 93256  -0.63  ...                 0                 0                 0
# 93337  -0.27  ...                 0                 0                 0
#
#        race_id_676153.0  race_id_677895.0  race_id_678763.0  race_id_679070.0  \
# 5510                  0                 0                 0                 0
# 5654                  0                 0                 0                 0
# 5661                  0                 0                 0                 0
# 6013                  0                 0                 0                 0
# 6999                  0                 0                 0                 0
# ...                 ...               ...               ...               ...
# 91856                 0                 0                 1                 0
# 92062                 0                 0                 0                 1
# 92937                 0                 0                 0                 0
# 93256                 0                 0                 0                 0
# 93337                 0                 0                 0                 0
#
#        race_id_680803.0  race_id_681242.0  race_id_681410.0
# 5510                  0                 0                 0
# 5654                  0                 0                 0
# 5661                  0                 0                 0
# 6013                  0                 0                 0
# 6999                  0                 0                 0
# ...                 ...               ...               ...
# 91856                 0                 0                 0
# 92062                 0                 0                 0
# 92937                 1                 0                 0
# 93256                 0                 1                 0
# 93337                 0                 0                 1
#
# [314 rows x 301 columns]

# %%
df1 = pd.get_dummies(df, columns=['horse_id'])
print(df1)
# Out:
#         race_id  1-101  1-102  1-103  1-104  1-105  1-106  1-107  1-108  \
# 5510   508904.0  0.800  0.440  0.060 -0.335  -0.36 -0.405 -0.475  -0.63
# 5654   509272.0  0.200  0.180  0.020  0.000   0.00  0.000  0.000  -0.27
# 5661   509272.0  0.200  0.180  0.020  0.000   0.00  0.000  0.000  -1.11
# 6013   509999.0 -0.330 -0.380 -0.140 -0.190  -0.36 -0.280 -0.630  -0.16
# 6999   511410.0 -0.390 -0.280 -0.350 -0.150  -0.18 -0.160 -0.640  -0.01
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 91856  678763.0 -0.670 -0.460 -0.370 -0.070  -0.47  0.080  0.010  -0.43
# 92062  679070.0 -0.200  0.310  0.500 -0.280  -0.33  0.130  0.810   1.13
# 92937  680803.0  0.710  0.200  0.530 -0.160   0.42 -0.130 -0.250   1.27
# 93256  681242.0 -0.490 -0.690 -0.850  0.800   0.13 -0.060 -0.290   0.34
# 93337  681410.0  0.205 -0.075 -0.185 -0.500  -0.48 -0.400 -0.010  -0.52
#
#        1-109  ...  horse_id_903118.0  horse_id_903163.0  horse_id_905867.0  \
# 5510    1.16  ...                  0                  0                  0
# 5654    0.59  ...                  0                  0                  0
# 5661   -0.45  ...                  0                  0                  0
# 6013   -0.39  ...                  0                  0                  0
# 6999    0.07  ...                  0                  0                  0
# ...      ...  ...                ...                ...                ...
# 91856  -0.84  ...                  0                  0                  0
# 92062   0.11  ...                  0                  0                  0
# 92937  -1.06  ...                  0                  0                  0
# 93256  -0.63  ...                  0                  1                  0
# 93337  -0.27  ...                  0                  0                  0
#
#        horse_id_906232.0  horse_id_907158.0  horse_id_963933.0  \
# 5510                   0                  0                  0
# 5654                   0                  0                  0
# 5661                   0                  0                  0
# 6013                   0                  0                  0
# 6999                   0                  0                  0
# ...                  ...                ...                ...
# 91856                  0                  0                  0
# 92062                  0                  0                  0
# 92937                  0                  0                  0
# 93256                  0                  0                  0
# 93337                  0                  0                  0
#
#        horse_id_980332.0  horse_id_997760.0  horse_id_1002581.0  \
# 5510                   0                  0                   0
# 5654                   0                  0                   0
# 5661                   0                  0                   0
# 6013                   0                  0                   0
# 6999                   0                  0                   0
# ...                  ...                ...                 ...
# 91856                  0                  0                   0
# 92062                  0                  0                   0
# 92937                  0                  0                   0
# 93256                  0                  0                   0
# 93337                  0                  0                   0
#
#        horse_id_1012378.0
# 5510                    0
# 5654                    0
# 5661                    0
# 6013                    0
# 6999                    0
# ...                   ...
# 91856                   0
# 92062                   0
# 92937                   0
# 93256                   0
# 93337                   0
#
# [314 rows x 373 columns]
